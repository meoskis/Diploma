# %%
import pandas as pd
import numpy as np
import networkx as nx
from bs4 import BeautifulSoup
import requests
import codecs
import os
from lxml import etree
import json
import unicodedata
import string

path = '/content/drive/MyDrive/ДИПЛОМ/Списки компаний/Парсеры для карточек компаний/'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_excel('/content/drive/MyDrive/ДИПЛОМ/Списки компаний/Парсеры для карточек компаний/company_list_fst_iteration.xlsx', converters={'ИНН':str})
data['ИНН'] = data['ИНН'].astype(str)
data.drop(['№', 'Столбец1', 'Есть выгрузка', 'Место по итогам 2020 года',
           'Объем реализации в 2021 году (млн. рублей)*', 'Объем реализации в 2020 году (млн. рублей)*',
           'Темпы роста выручки за год (%)', 'Объем реализации в 2021 году (млн. долларов)', 'Прибыль до налогообложения в 2021 году (млн. рублей)',
           'Чистая прибыль в 2021 году (млн. рублей)', 'Тип отчетности'], axis=1, inplace=True)
data.rename(columns={'Название':'company_file','ИНН':'inn_file','Отрасль':'industry_file'}, inplace=True)
data
# Out:
#                       company_file    inn_file  \
# 0     «КТЗ», промышленный оператор  9704082895
# 1                  «Автомир-Трейд»  7730569353
# 2                  «Джи Пи Си Рус»  7703400140
# 3           «Самотлорнефтепромхим»  8603118208
# 4                  «Мосметрострой»  7710068052
# ..                             ...         ...
# 583                       X5 Group  7733571872
# 584                            РЖД  7708503727
# 585  «Роснефть», нефтяная компания  7706107510
# 586                       «ЛУКОЙЛ»  7708004767
# 587                      «Газпром»  7736050003
#
#                                          industry_file
# 0                                     оптовая торговля
# 1                                   розничная торговля
# 2                                     платежный сервис
# 3                                   сервисные компании
# 4    инжиниринг, промышленно-инфраструктурное строи...
# ..                                                 ...
# 583                                 розничная торговля
# 584                              транспорт и логистика
# 585             нефтяная и нефтегазовая промышленность
# 586             нефтяная и нефтегазовая промышленность
# 587             нефтяная и нефтегазовая промышленность
#
# [588 rows x 3 columns]

# %%
list_of_smi_publications = pd.DataFrame(os.listdir(path+'company_smi_publications'), dtype=str)
list_of_smi_publications.rename(columns={0:'inn_smi_publications'}, inplace=True)
list_of_smi_publications['inn_smi_publications'] = list_of_smi_publications['inn_smi_publications'].str.replace('.html', '', regex=False).astype(str)
list_of_smi_publications
# Out:
#     inn_smi_publications
# 0             9704082895
# 1             7730569353
# 2             7703400140
# 3             8603118208
# 4             7710068052
# ..                   ...
# 558           7708503727
# 559           7706107510
# 560           7708004767
# 561           7736050003
# 562           7022000310
#
# [563 rows x 1 columns]

# %%
list_of_company_main_cards = pd.DataFrame(os.listdir(path+'company_main_cards'))
list_of_company_main_cards.rename(columns={0:'inn_company_main_cards'}, inplace=True)
list_of_company_main_cards['inn_company_main_cards'] = list_of_company_main_cards['inn_company_main_cards'].str.replace('.html', '', regex=False)
list_of_company_main_cards
# Out:
#     inn_company_main_cards
# 0               9704082895
# 1               7730569353
# 2               7703400140
# 3               8603118208
# 4               7710068052
# ..                     ...
# 574             7708503727
# 575             7706107510
# 576             7708004767
# 577             7736050003
# 578             7022000310
#
# [579 rows x 1 columns]

# %%
all_inn_data = pd.merge(list_of_smi_publications, list_of_company_main_cards, how='inner', left_on='inn_smi_publications', right_on='inn_company_main_cards')
all_inn_data
# Out:
#     inn_smi_publications inn_company_main_cards
# 0             9704082895             9704082895
# 1             7730569353             7730569353
# 2             7703400140             7703400140
# 3             8603118208             8603118208
# 4             7710068052             7710068052
# ..                   ...                    ...
# 558           7708503727             7708503727
# 559           7706107510             7706107510
# 560           7708004767             7708004767
# 561           7736050003             7736050003
# 562           7022000310             7022000310
#
# [563 rows x 2 columns]

# %%
data = data.merge(all_inn_data, how='left', left_on='inn_file', right_on='inn_smi_publications')
data
# Out:
#                       company_file    inn_file  \
# 0     «КТЗ», промышленный оператор  9704082895
# 1                  «Автомир-Трейд»  7730569353
# 2                  «Джи Пи Си Рус»  7703400140
# 3           «Самотлорнефтепромхим»  8603118208
# 4                  «Мосметрострой»  7710068052
# ..                             ...         ...
# 583                       X5 Group  7733571872
# 584                            РЖД  7708503727
# 585  «Роснефть», нефтяная компания  7706107510
# 586                       «ЛУКОЙЛ»  7708004767
# 587                      «Газпром»  7736050003
#
#                                          industry_file inn_smi_publications  \
# 0                                     оптовая торговля           9704082895
# 1                                   розничная торговля           7730569353
# 2                                     платежный сервис           7703400140
# 3                                   сервисные компании           8603118208
# 4    инжиниринг, промышленно-инфраструктурное строи...           7710068052
# ..                                                 ...                  ...
# 583                                 розничная торговля           7733571872
# 584                              транспорт и логистика           7708503727
# 585             нефтяная и нефтегазовая промышленность           7706107510
# 586             нефтяная и нефтегазовая промышленность           7708004767
# 587             нефтяная и нефтегазовая промышленность           7736050003
#
#     inn_company_main_cards
# 0               9704082895
# 1               7730569353
# 2               7703400140
# 3               8603118208
# 4               7710068052
# ..                     ...
# 583             7733571872
# 584             7708503727
# 585             7706107510
# 586             7708004767
# 587             7736050003
#
# [588 rows x 5 columns]

# %% [markdown]
# ## Проверка: открылась ли вкладка еще при скачивании карточки

# %%
data_clean = data.dropna()
data_clean
# Out:
#                       company_file    inn_file  \
# 0     «КТЗ», промышленный оператор  9704082895
# 1                  «Автомир-Трейд»  7730569353
# 2                  «Джи Пи Си Рус»  7703400140
# 3           «Самотлорнефтепромхим»  8603118208
# 4                  «Мосметрострой»  7710068052
# ..                             ...         ...
# 583                       X5 Group  7733571872
# 584                            РЖД  7708503727
# 585  «Роснефть», нефтяная компания  7706107510
# 586                       «ЛУКОЙЛ»  7708004767
# 587                      «Газпром»  7736050003
#
#                                          industry_file inn_smi_publications  \
# 0                                     оптовая торговля           9704082895
# 1                                   розничная торговля           7730569353
# 2                                     платежный сервис           7703400140
# 3                                   сервисные компании           8603118208
# 4    инжиниринг, промышленно-инфраструктурное строи...           7710068052
# ..                                                 ...                  ...
# 583                                 розничная торговля           7733571872
# 584                              транспорт и логистика           7708503727
# 585             нефтяная и нефтегазовая промышленность           7706107510
# 586             нефтяная и нефтегазовая промышленность           7708004767
# 587             нефтяная и нефтегазовая промышленность           7736050003
#
#     inn_company_main_cards
# 0               9704082895
# 1               7730569353
# 2               7703400140
# 3               8603118208
# 4               7710068052
# ..                     ...
# 583             7733571872
# 584             7708503727
# 585             7706107510
# 586             7708004767
# 587             7736050003
#
# [563 rows x 5 columns]

# %%
smi_card_path = path+'company_smi_publications/'

def organizations_checker(df, row_number):
  company_inn = str(df['inn_file'].iloc[row_number])
  print(company_inn)

  with open(smi_card_path+company_inn+'.html', 'r') as f:
    contents = f.read()

    soup = BeautifulSoup(contents, 'lxml')
    dom = etree.HTML(str(soup))

  side_panels = soup.find('div', {"class": "sidebar-filters"}).find_all('div', {'class': 'sidebar-filters__section sidebar-filters__section_no-delimiter'})
  ammt_side_panels = len(side_panels)

  org_panel_id = -1
  for panel in range(ammt_side_panels):
    name = dom.xpath(f'/html/body/div/div[1]/div[1]/div[1]/div[2]/div/div/div/div/div[3]/div[2]/div[2]/div[2]/div[1]/div/div[{panel+1}]/div/div/div/button/div/text()')
    if name:
      if name[0].upper() == 'ОРГАНИЗАЦИИ':
        org_panel_id = panel+1

  flag = -1
  if 'еще' in str(side_panels[org_panel_id-1]).lower():
    flag = 0
  else:
    flag = 1

  f.close()

  return flag

# %%
organizations_checker_marker = []

for row in range(data_clean.shape[0]):
  flg = organizations_checker(data_clean, row)
  organizations_checker_marker.append(flg)
# Out:
# 9704082895
# 7730569353
# 7703400140
# 8603118208
# 7710068052
# 1655049111
# 7709340842
# 9718221490
# 7719022542
# 7714775020
# 5042060699
# 7704758153
# 5029104266
# 7838418751
# 2315995868
# 5403145086
# 5047172389
# 7707073366
# 1654035998
# 4826022365
# 7705639173
# 1627005779
# 7705937571
# 7727696432
# 1655189422
# 6632004667
# 7710698978
# 7701655865
# 6663003800
# 7732121736
# 5046001101
# 4623004836
# 7717127211
# 5047105054
# 2922008546
# 4633037968
# 3814007314
# 3305051742
# 7703295463
# 4909105495
# 7810022460
# 5609087920
# 6229024796
# 9705118142
# 7707205911
# 6732075238
# 7709583813
# 3811125221
# 7730107662
# 7701004101
# 5001048893
# 4725001168
# 9715239467
# 4203001913
# 7811657720
# 7704160892
# 7709976356
# 0270007455
# 7718538045
# 7705189397
# 7705532790
# 7830001028
# 4216001565
# 7706236515
# 7703106050
# 7017286512
# 1001228754
# 7428007317
# 7702192017
# 7705005321
# 5827901723
# 4252012308
# 7710761161
# 7731530768
# 7729507377
# 7716641537
# 7705058323
# 8904075533
# 7702352454
# 5030041780
# 7814581879
# 3812100526
# 7705040943
# 3328430578
# 7327067461
# 7839326623
# 7719555477
# 7703248907
# 1303066789
# 7810349385
# 7706739893
# 7703635416
# 3328426780
# 5443005705
# 5027083476
# 7731316845
# 7736588909
# 7701879760
# 2308091759
# 7810249327
# 4633042206
# 7704459330
# 7729657870
# 5501100816
# 7706288496
# 7804568558
# 4205003440
# 6670413340
# 7705255201
# 7809008119
# 1650292810
# 7704579700
# 3905069220
# 3327122348
# 7709222373
# 7705772224
# 6315222985
# 7401000473
# 4214000252
# 6627001318
# 2723188252
# 7830000426
# 7705989700
# 6670381056
# 7826156685
# 1650161470
# 5007067042
# 7708797192
# 7717654289
# 7804069580
# 7720522853
# 6367052981
# 7730117815
# 7704216778
# 6025009824
# 7413000630
# 1659091192
# 7743101210
# 7701753020
# 7706241963
# 7710668349
# 7734003657
# 6704000505
# 5404151283
# 6164266561
# 7703068485
# 7709770002
# 7704537299
# 7705492690
# 7728115183
# 5904123809
# 7724338125
# 5604000700
# 4223035452
# 6234131659
# 4214033674
# 2459007621
# 7701350084
# 7701380579
# 7101006354
# 7708607959
# 7703400608
# 7202197786
# 7703508520
# 7830000970
# 0275038496
# 3123100360
# 5245000448
# 7710106212
# 7703374404
# 7725594604
# 7722582752
# 3250521869
# 5047095543
# 7704676655
# 5047149534
# 7813252159
# 9722041250
# 5044018861
# 2903000446
# 2902060361
# 7706092944
# 7736655834
# 4715019631
# 5032292612
# 4027091179
# 7721147115
# 4345217731
# 5262218620
# 5407025576
# 7715034360
# 6671156423
# 7715729877
# 1657036630
# 7118004789
# 8608049090
# 5260900010
# 7705935687
# 2352044518
# 7713628217
# 7705880068
# 7726044240
# 7703813034
# 5029169023
# 3252005997
# 8300120014
# 7743911253
# 4704012472
# 7721562305
# 7706017070
# 7719723690
# 7606053324
# 7743543232
# 7819301797
# 7728551510
# 7802312751
# 2720030404
# 7806027191
# 5011021227
# 7705018169
# 5038114542
# 7705098679
# 6166019871
# 7730248021
# 7704217309
# 4223055709
# 2465102746
# 7714724594
# 7721844807
# 7725776121
# 7712040285
# 7728795958
# 7802772445
# 8709009294
# 7743816842
# 7707803527
# 7707424367
# 7601001509
# 3122000300
# 5257003806
# 7704648707
# 7713140469
# 7715397999
# 7714037390
# 0277077282
# 8609000160
# 7722753969
# 7745000111
# 5603048611
# 1106019518
# 7104525439
# 3905011678
# 7701716677
# 7704244246
# 7731585968
# 7708678325
# 7717582404
# 7834005168
# 7705705370
# 2309001660
# 2315078029
# 2465008567
# 7706277053
# 4028069779
# 7729763331
# 4217204769
# 3328434156
# 7706800837
# 7726445147
# 5258054000
# 7827004484
# 6829012680
# 1651024807
# 2460069527
# 7709678550
# 3913009739
# 7729588182
# 3110009570
# 7743580770
# 1831089218
# 7743578549
# 5003116490
# 1655202105
# 6606003385
# 6658388288
# 7730710905
# 7726059896
# 7017187800
# 5012000639
# 9701104646
# 6450925977
# 4205000908
# 6623074298
# 7736313319
# 6606021264
# 9715010229
# 6167055777
# 5902202276
# 7734445616
# 3321020710
# 7702842787
# 7701984274
# 0274036993
# 6607000556
# 5262036363
# 5611037405
# 7720403415
# 7714709349
# 5032048798
# 7705475711
# 7729607406
# 5021013384
# 4025413896
# 7708525142
# 7710302785
# 7702764909
# 7732121398
# 7118018781
# 1121003135
# 7705840940
# 7717625418
# 2328000083
# 7733646084
# 2451000818
# 7447010227
# 8603133326
# 6310000160
# 5032073106
# 7705634425
# 0268008010
# 7710044140
# 6166048181
# 4217107518
# 5024177951
# 7725104641
# 7720484492
# 7204002873
# 7704630033
# 7730157021
# 1657082308
# 1650131524
# 0264015786
# 7451279527
# 5258056945
# 7731537410
# 7203162698
# 4217126359
# 7725216105
# 7709680944
# 7729265128
# 5913001268
# 5047210316
# 7734135124
# 7704726183
# 7802059185
# 7802849641
# 5406192366
# 9731058933
# 7725806898
# 5020037784
# 7705183476
# 9703017050
# 7704017596
# 7814116230
# 6320005915
# 2320109650
# 7721793895
# 7720261827
# 7729481489
# 3528079131
# 7403005526
# 7838395215
# 5032277847
# 7729705354
# 5024048000
# 7709751313
# 7803002209
# 7715568411
# 7713587786
# 7701215046
# 7702691545
# 6608003013
# 7743036465
# 6671163413
# 4217102358
# 3808208157
# 7802348846
# 7706806518
# 7842337791
# 7729418511
# 2323025302
# 7733556360
# 7701791321
# 7722489009
# 3913501820
# 7718134701
# 1434045743
# 7708632345
# 8904047896
# 7704492055
# 7714617793
# 5260200603
# 7713085659
# 6901067107
# 6162015019
# 7714626332
# 2310175205
# 7725497022
# 7714186804
# 7804526950
# 2225074005
# 7702060116
# 7727504170
# 7017405576
# 7113502396
# 7714790325
# 7743543761
# 5075018950
# 7701639976
# 7743856281
# 7810245481
# 7743001840
# 2902059091
# 2310040800
# 7728551528
# 7705133757
# 3913011336
# 7704582421
# 7713688946
# 7743792870
# 7714572888
# 7702521529
# 6658252583
# 7708591995
# 6674121179
# 6671197148
# 7709787790
# 0274110679
# 7841322249
# 7710045520
# 7736227885
# 0411075740
# 7709259743
# 5045016560
# 7718979307
# 5448100656
# 7702038150
# 5047076050
# 6685099285
# 7718560636
# 2370000496
# 7734443270
# 7022000310
# 7729355029
# 5009072150
# 5074053542
# 6151012111
# 6670061296
# 8910002621
# 7811365157
# 6165161667
# 5257056036
# 2308128110
# 7704548011
# 5036065113
# 7017094419
# 7726311464
# 7727162286
# 7826087713
# 5247004695
# 4234001215
# 7705739450
# 7743931676
# 4028021946
# 7706284124
# 3122503751
# 7701885820
# 7801463902
# 7805104870
# 3808066311
# 7721040281
# 7704218694
# 7704784450
# 7728278043
# 7703623202
# 7721546864
# 7705060700
# 5047085094
# 7724490000
# 7703270067
# 7712107050
# 5408130693
# 7713056834
# 4716016979
# 7707743204
# 3906072056
# 7728731619
# 5047045359
# 4205049090
# 1650032058
# 7717133960
# 7719269331
# 7707016368
# 7728674093
# 6606013640
# 7703608910
# 7705541227
# 8904002359
# 6320002223
# 5911029807
# 7723199790
# 7715354473
# 5036045205
# 7707017509
# 1433000147
# 7713076301
# 7710390358
# 7703386329
# 7812014560
# 5042059767
# 5047254063
# 7703389295
# 7707767220
# 7710298176
# 7703370008
# 2460066195
# 7736216869
# 7736520080
# 7736035485
# 7710373095
# 5029069967
# 7708619320
# 7703647595
# 7707548740
# 7814148471
# 7713011336
# 7712040126
# 7709602713
# 2540167061
# 7707049388
# 7708129854
# 7727547261
# 5018108484
# 7703104630
# 3528000597
# 7414003633
# 5003052454
# 7701225358
# 7706061801
# 3906382033
# 6316031581
# 4823006703
# 1644003838
# 8401005730
# 7706413348
# 2309085638
# 8602060555
# 7704274402
# 7733571872
# 7708503727
# 7706107510
# 7708004767
# 7736050003

# %%
np.mean(organizations_checker_marker)
# Out:
# 0.8528896672504378

# %%
data_clean['open_orgs_checker'] = organizations_checker_marker
data_clean
# Out:
# <ipython-input-11-1b28d6974358>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_clean['open_orgs_checker'] = organizations_checker_marker
#                       company_file    inn_file  \
# 0     «КТЗ», промышленный оператор  9704082895
# 1                  «Автомир-Трейд»  7730569353
# 2                  «Джи Пи Си Рус»  7703400140
# 3           «Самотлорнефтепромхим»  8603118208
# 4                  «Мосметрострой»  7710068052
# ..                             ...         ...
# 583                       X5 Group  7733571872
# 584                            РЖД  7708503727
# 585  «Роснефть», нефтяная компания  7706107510
# 586                       «ЛУКОЙЛ»  7708004767
# 587                      «Газпром»  7736050003
#
#                                          industry_file inn_smi_publications  \
# 0                                     оптовая торговля           9704082895
# 1                                   розничная торговля           7730569353
# 2                                     платежный сервис           7703400140
# 3                                   сервисные компании           8603118208
# 4    инжиниринг, промышленно-инфраструктурное строи...           7710068052
# ..                                                 ...                  ...
# 583                                 розничная торговля           7733571872
# 584                              транспорт и логистика           7708503727
# 585             нефтяная и нефтегазовая промышленность           7706107510
# 586             нефтяная и нефтегазовая промышленность           7708004767
# 587             нефтяная и нефтегазовая промышленность           7736050003
#
#     inn_company_main_cards  open_orgs_checker
# 0               9704082895                  1
# 1               7730569353                  1
# 2               7703400140                  1
# 3               8603118208                  1
# 4               7710068052                  1
# ..                     ...                ...
# 583             7733571872                  1
# 584             7708503727                  0
# 585             7706107510                  1
# 586             7708004767                  0
# 587             7736050003                  0
#
# [563 rows x 6 columns]

# %%
data_for_next_step = data.merge(data_clean[['inn_file', 'open_orgs_checker']], how='left', on='inn_file')
data_for_next_step['open_orgs_checker'] = np.where((data_for_next_step['open_orgs_checker'] == 0) | (data_for_next_step['open_orgs_checker'].isna()), np.nan, 1)
data_for_next_step.drop(['inn_smi_publications', 'inn_company_main_cards'], axis=1, inplace=True)
data_for_next_step
# Out:
#                       company_file    inn_file  \
# 0     «КТЗ», промышленный оператор  9704082895
# 1                  «Автомир-Трейд»  7730569353
# 2                  «Джи Пи Си Рус»  7703400140
# 3           «Самотлорнефтепромхим»  8603118208
# 4                  «Мосметрострой»  7710068052
# ..                             ...         ...
# 583                       X5 Group  7733571872
# 584                            РЖД  7708503727
# 585  «Роснефть», нефтяная компания  7706107510
# 586                       «ЛУКОЙЛ»  7708004767
# 587                      «Газпром»  7736050003
#
#                                          industry_file  open_orgs_checker
# 0                                     оптовая торговля                1.0
# 1                                   розничная торговля                1.0
# 2                                     платежный сервис                1.0
# 3                                   сервисные компании                1.0
# 4    инжиниринг, промышленно-инфраструктурное строи...                1.0
# ..                                                 ...                ...
# 583                                 розничная торговля                1.0
# 584                              транспорт и логистика                NaN
# 585             нефтяная и нефтегазовая промышленность                1.0
# 586             нефтяная и нефтегазовая промышленность                NaN
# 587             нефтяная и нефтегазовая промышленность                NaN
#
# [588 rows x 4 columns]

# %% [markdown]
# ##

# %%
data_for_next_step = data_for_next_step[data_for_next_step['open_orgs_checker'].isna()]
data_for_next_step
# Out:
#                                company_file    inn_file  \
# 17                         Торговый дом ЦУМ  7707073366
# 21                                «Аммоний»  1627005779
# 22   «Металлоломная компания ОМК-Экометалл»  7705937571
# 39                «Модерн Машинери Фар Ист»  4909105495
# 56                                   АйТеко  7704160892
# ..                                      ...         ...
# 581                   «Сургутнефтегаз», ПАО  8602060555
# 582     Государственная корпорация «Ростех»  7704274402
# 584                                     РЖД  7708503727
# 586                                «ЛУКОЙЛ»  7708004767
# 587                               «Газпром»  7736050003
#
#                                    industry_file  open_orgs_checker
# 17                            розничная торговля                NaN
# 21   химическая и нефтехимическая промышленность                NaN
# 22                            черная металлургия                NaN
# 39                              оптовая торговля                NaN
# 56                     информационные технологии                NaN
# ..                                           ...                ...
# 581       нефтяная и нефтегазовая промышленность                NaN
# 582                               машиностроение                NaN
# 584                        транспорт и логистика                NaN
# 586       нефтяная и нефтегазовая промышленность                NaN
# 587       нефтяная и нефтегазовая промышленность                NaN
#
# [101 rows x 4 columns]

# %%
data_for_next_step.to_excel('/content/drive/MyDrive/ДИПЛОМ/Списки компаний/Парсеры для карточек компаний/data_for_next_step_2.xlsx', index=False)

# %% [markdown]
# ### Считывание основной информации

# %%
data_for_info = data.merge(data_clean[['inn_file', 'open_orgs_checker']], how='left', on='inn_file')
data_for_info = data_for_info[data_for_info['open_orgs_checker'] == 1]

# %%
data_for_info
# Out:
#                                           company_file    inn_file  \
# 0                         «КТЗ», промышленный оператор  9704082895
# 1                                      «Автомир-Трейд»  7730569353
# 2                                      «Джи Пи Си Рус»  7703400140
# 3                               «Самотлорнефтепромхим»  8603118208
# 4                                      «Мосметрострой»  7710068052
# ..                                                 ...         ...
# 571                       «Мегаполис», группа компаний  5003052454
# 573                                 «Транснефть» (ПАО)  7706061801
# 576  ПАО «Новолипецкий металлургический комбинат» (...  4823006703
# 583                                           X5 Group  7733571872
# 585                      «Роснефть», нефтяная компания  7706107510
#
#                                          industry_file inn_smi_publications  \
# 0                                     оптовая торговля           9704082895
# 1                                   розничная торговля           7730569353
# 2                                     платежный сервис           7703400140
# 3                                   сервисные компании           8603118208
# 4    инжиниринг, промышленно-инфраструктурное строи...           7710068052
# ..                                                 ...                  ...
# 571                                   оптовая торговля           5003052454
# 573                              транспорт и логистика           7706061801
# 576                                 черная металлургия           4823006703
# 583                                 розничная торговля           7733571872
# 585             нефтяная и нефтегазовая промышленность           7706107510
#
#     inn_company_main_cards  open_orgs_checker
# 0               9704082895                1.0
# 1               7730569353                1.0
# 2               7703400140                1.0
# 3               8603118208                1.0
# 4               7710068052                1.0
# ..                     ...                ...
# 571             5003052454                1.0
# 573             7706061801                1.0
# 576             4823006703                1.0
# 583             7733571872                1.0
# 585             7706107510                1.0
#
# [479 rows x 6 columns]

# %%
smi_card_path = path+'company_smi_publications/'

def parser(file_name):
  with open(file_name, 'r') as f:

    contents = f.read()
    soup = BeautifulSoup(contents, 'lxml')

    # Достаем неазвание компании
    company_name = soup.html.title.get_text()

    # print(file_name)
    # print(company_name)

    # Находим боковые панели со значениями
    sideback_panel = soup.find('div', {"class": "sidebar-filters"}).find_all('div', {"class": "sidebar-filters__section sidebar-filters__section_no-delimiter"})

    # Находим наименования боковых панелей
    sideback_panel_titles = soup.find('div', {"class": "sidebar-filters"}).find_all('div', {'class': 'sp-facet__title-spoiler'})

    # Находим id в которой ссодержится информация по организациям
    orgs_id = -1
    for a in range(len(sideback_panel_titles)):
      if sideback_panel_titles[a].get_text() == 'Организации':
        orgs_id = a+1 # сначала публикации

    # Тесты
    # print(len(sideback_panel))
    test = len(sideback_panel)-orgs_id
    all_orgs = []

    # Находим список организаций
    organizations = sideback_panel[orgs_id].find('div', {"class": "sp-facet"}).find_all('button', {'class':'sp-fake-link sidebar-filter'})
    for org in organizations:
      org_name = org.find('div', {'class':'sidebar-filter__label-name'}).get_text()
      ammt = org.find('div', {'class':'sidebar-filter__count'}).get_text()
      all_orgs.append([org_name, ammt])

    return (test, {file_name.split('/')[-1].split('.')[0]:all_orgs})

# %%
list_of_fls = (data_for_info['inn_file'] + '.html').to_list()

mentioned_orgs = {}
result = []

for fl in range(len(list_of_fls)):
  html_fl_path = smi_card_path + list_of_fls[fl]
  res, comp = parser(html_fl_path)
  result.append(res)
  mentioned_orgs.update(comp)

# %%
data_for_info['company_interfax'] = list(mentioned_orgs.keys())
data_for_info

# %%
for key in mentioned_orgs.keys():
  for org in range(len(mentioned_orgs[key])):
    mentioned_orgs[key][org][0] = mentioned_orgs[key][org][0].replace(u'\xa0', u' ')
    mentioned_orgs[key][org][1] = mentioned_orgs[key][org][1].replace(u'\xa0', u' ')

# %%
with open('/content/drive/MyDrive/ДИПЛОМ/Списки компаний/Парсеры для карточек компаний/orgs_smi_info.json', 'w') as f:
    json.dump(mentioned_orgs, f)

# %%
company_in_org_list = []
for key in mentioned_orgs.keys():
  for value in mentioned_orgs[key]:
    company_in_org_list.append(value[0])
print(len(company_in_org_list))

company_in_org_list = list(set(company_in_org_list))
print(len(company_in_org_list))
# Out:
# 39466
# 11834

# %%
company_in_org_df = pd.DataFrame(company_in_org_list, columns=['company_name'])
company_in_org_df.to_csv('/content/drive/MyDrive/ДИПЛОМ/Списки компаний/Парсеры для карточек компаний/company_in_org_df_2.csv', index=False)

# %%
data_for_info
# Out:
#                                           company_file    inn_file  \
# 0                         «КТЗ», промышленный оператор  9704082895
# 1                                      «Автомир-Трейд»  7730569353
# 2                                      «Джи Пи Си Рус»  7703400140
# 3                               «Самотлорнефтепромхим»  8603118208
# 4                                      «Мосметрострой»  7710068052
# ..                                                 ...         ...
# 571                       «Мегаполис», группа компаний  5003052454
# 573                                 «Транснефть» (ПАО)  7706061801
# 576  ПАО «Новолипецкий металлургический комбинат» (...  4823006703
# 583                                           X5 Group  7733571872
# 585                      «Роснефть», нефтяная компания  7706107510
#
#                                          industry_file inn_smi_publications  \
# 0                                     оптовая торговля           9704082895
# 1                                   розничная торговля           7730569353
# 2                                     платежный сервис           7703400140
# 3                                   сервисные компании           8603118208
# 4    инжиниринг, промышленно-инфраструктурное строи...           7710068052
# ..                                                 ...                  ...
# 571                                   оптовая торговля           5003052454
# 573                              транспорт и логистика           7706061801
# 576                                 черная металлургия           4823006703
# 583                                 розничная торговля           7733571872
# 585             нефтяная и нефтегазовая промышленность           7706107510
#
#     inn_company_main_cards  open_orgs_checker
# 0               9704082895                1.0
# 1               7730569353                1.0
# 2               7703400140                1.0
# 3               8603118208                1.0
# 4               7710068052                1.0
# ..                     ...                ...
# 571             5003052454                1.0
# 573             7706061801                1.0
# 576             4823006703                1.0
# 583             7733571872                1.0
# 585             7706107510                1.0
#
# [479 rows x 6 columns]

# %% [markdown]
# ### Проверка соотвествия ИННов внутри файлов

# %%
company_smi_publications_path = path+'company_smi_publications/'

lst_of_companies = (data_for_info['inn_file'] + '.html').to_list()

# %%
def smi_inn_crawler(file_name):
  with open(company_smi_publications_path+file_name, 'r') as f:

    contents = f.read()
    soup = BeautifulSoup(contents, 'lxml')

  dom = etree.HTML(str(soup))
  company_main_info = {}
  for i in range(1,5):
    info_type = dom.xpath(f'/html/body/div/div[1]/div[1]/div[1]/div[1]/div/div/div[2]/div/span[{i}]/span/span/span/span/text()')[0][:-1]
    info = dom.xpath(f'/html/body/div/div[1]/div[1]/div[1]/div[1]/div/div/div[2]/div/span[{i}]/span/span/span/span/span/span/span/text()')[0]
    company_main_info[info_type] = info

  return company_main_info

# %%
smi_info_checker = []

for comp in lst_of_companies:
  print(comp)
  smi_info_checker.append(smi_inn_crawler(comp))

# %%
res = pd.DataFrame(smi_info_checker)
res
# Out:
#               ОГРН         ИНН        КПП      ОКПО
# 0    1217700375991  9704082895  210001001  51974376
# 1    1077761079263  7730569353  771801001  83121511
# 2    1157746967510  7703400140  774301001  51166895
# 3    1048600521408  8603118208  860301001  74733014
# 4    1027739002378  7710068052  770701001  01387120
# ..             ...         ...        ...       ...
# 482  1045000923967  5003052454  500301001  75219395
# 483  1027700049486  7706061801  770301001  00044463
# 484  1024800823123  4823006703  482301001  05757665
# 485  1067746744955  7733571872  773301001  96042871
# 486  1027700043502  7706107510  770601001  00044428
#
# [487 rows x 4 columns]

# %%
data_for_info
# Out:
#                                           company_file    inn_file  \
# 0                         «КТЗ», промышленный оператор  9704082895
# 1                                      «Автомир-Трейд»  7730569353
# 2                                      «Джи Пи Си Рус»  7703400140
# 3                               «Самотлорнефтепромхим»  8603118208
# 4                                      «Мосметрострой»  7710068052
# ..                                                 ...         ...
# 571                       «Мегаполис», группа компаний  5003052454
# 573                                 «Транснефть» (ПАО)  7706061801
# 576  ПАО «Новолипецкий металлургический комбинат» (...  4823006703
# 583                                           X5 Group  7733571872
# 585                      «Роснефть», нефтяная компания  7706107510
#
#                                          industry_file inn_smi_publications  \
# 0                                     оптовая торговля           9704082895
# 1                                   розничная торговля           7730569353
# 2                                     платежный сервис           7703400140
# 3                                   сервисные компании           8603118208
# 4    инжиниринг, промышленно-инфраструктурное строи...           7710068052
# ..                                                 ...                  ...
# 571                                   оптовая торговля           5003052454
# 573                              транспорт и логистика           7706061801
# 576                                 черная металлургия           4823006703
# 583                                 розничная торговля           7733571872
# 585             нефтяная и нефтегазовая промышленность           7706107510
#
#     inn_company_main_cards  open_orgs_checker          company_interfax
# 0               9704082895                1.0                 ООО "КТЗ"
# 1               7730569353                1.0       ООО "АВТОМИР-ТРЕЙД"
# 2               7703400140                1.0       ООО "ДЖИ ПИ СИ РУС"
# 3               8603118208                1.0                  АО"СНПХ"
# 4               7710068052                1.0        АО "МОСМЕТРОСТРОЙ"
# ..                     ...                ...                       ...
# 571             5003052454                1.0        АО "ТК "МЕГАПОЛИС"
# 573             7706061801                1.0          ПАО "ТРАНСНЕФТЬ"
# 576             4823006703                1.0                ПАО "НЛМК"
# 583             7733571872                1.0  ООО "ИКС 5 РИТЕЙЛ ГРУПП"
# 585             7706107510                1.0        ПАО "НК "РОСНЕФТЬ"
#
# [487 rows x 7 columns]

# %%
res = pd.DataFrame(smi_info_checker)
test = pd.merge(res, data_for_info, right_on='inn_file', left_on='ИНН', how='right')
# test = test.dropna()

# %%
test[test['ОГРН'].isna()]
# Out:
#     ОГРН  ИНН  КПП ОКПО                       company_file    inn_file  \
# 42   NaN  NaN  NaN  NaN            Россети Северный Кавказ  2632082033
# 84   NaN  NaN  NaN  NaN  «Энергосбытовая компания «Восток»  7705424509
# 375  NaN  NaN  NaN  NaN   «Ресурс», группа агропредприятий  7736511906
# 399  NaN  NaN  NaN  NaN           «Пепсико Холдингс» (ООО)  7705034202
# 412  NaN  NaN  NaN  NaN                     «Илим», группа  7840346335
# 423  NaN  NaN  NaN  NaN                        «Т2 Мобайл»  7743895280
# 468  NaN  NaN  NaN  NaN                           «Т Плюс»  6315376946
# 481  NaN  NaN  NaN  NaN                     «МХК «ЕвроХим»  7721230290
#
#                                          industry_file inn_smi_publications  \
# 42                                   электроэнергетика           2632082033
# 84                         энергосбытовая деятельность           7705424509
# 375                          агропромышленный комплекс           7736511906
# 399                             пищевая промышленность           7705034202
# 412  лесная, деревообрабатывающая и целлюлозно-бума...           7840346335
# 423                           телекоммуникации и связь           7743895280
# 468                                  электроэнергетика           6315376946
# 481        химическая и нефтехимическая промышленность           7721230290
#
#     inn_company_main_cards  open_orgs_checker   company_interfax
# 42              2632082033                1.0   АО "ЧЕЧЕНЭНЕРГО"
# 84              7705424509                1.0     АО "ЕРИЦ ЯНАО"
# 375             7736511906                1.0  ООО "ГАП "РЕСУРС"
# 399             7705034202                1.0  ООО "ЛЕБЕДЯНСКИЙ"
# 412             7840346335                1.0    АО "ИЛИМ ГОФРА"
# 423             7743895280                1.0  АО "МИЛЛИКОМ НТК"
# 468             6315376946                1.0      ООО "ИТ ПЛЮС"
# 481             7721230290                1.0       ООО "ЕХСЗ-2"

# %%
test[test['inn_file'] != test['ИНН']]
# Out:
#                                         company_file    inn_file  \
# 10                                      «КРКА Фарма»  5042060699
# 11                            "Торговый дом Локотех"  7704758153
# 12                «Московская пивоваренная компания»  5029104266
# 13                       ЦКБ морской техники "Рубин"  7838418751
# 14                  "Новороссийский прокатный завод"  2315995868
# ..                                               ...         ...
# 382        «Томинский горно-обогатительный комбинат»  7403005526
# 383  «Объединенная судостроительная корпорация» (АО)  7838395215
# 384                                   «Меркури Мода»  5032277847
# 385                       «Верный», сеть универсамов  7729705354
# 386                                         «Биокад»  5024048000
#
#                        industry_file inn_smi_publications  \
# 10                  оптовая торговля           5042060699
# 11                  оптовая торговля           7704758153
# 12            пищевая промышленность           5029104266
# 13                    машиностроение           7838418751
# 14                черная металлургия           2315995868
# ..                               ...                  ...
# 382              цветная металлургия           7403005526
# 383                   машиностроение           7838395215
# 384               розничная торговля           5032277847
# 385               розничная торговля           7729705354
# 386  фармацевтическая промышленность           5024048000
#
#     inn_company_main_cards  open_orgs_checker           ОГРН         ИНН  \
# 10              5042060699                1.0  1107746515887  7704758153
# 11              7704758153                1.0  1075029007855  5029104266
# 12              5029104266                1.0  1089848051116  7838418751
# 13              7838418751                1.0  1172375048196  2315995868
# 14              2315995868                1.0  1025401306116  5403145086
# ..                     ...                ...            ...         ...
# 382             7403005526                1.0  1147746461422  7718979307
# 383             7838395215                1.0  1025405624430  5448100656
# 384             5032277847                1.0  1065047056348  5047076050
# 385             7729705354                1.0  1156658068973  6685099285
# 386             5024048000                1.0  1124811000093  4811023542
#
#            КПП      ОКПО
# 10   770901001  66886637
# 11   502901001  81625934
# 12   783801001  07510551
# 13   615501001  16098811
# 14   771701001  54397324
# ..         ...       ...
# 382  771801001  29457298
# 383  544801001  18014126
# 384  504701001  96283528
# 385  668501001  41735951
# 386  481101001  00336929
#
# [316 rows x 10 columns]

# %% [markdown]
# ### Дальнейшая обработка

# %%
reversed_data = {}
for key, values in data.items():
  for value in values:
    reversed_data.setdefault(value, set()).add(key)

# %%
orgs_count = {org: [len(reversed_data[org]), reversed_data[org]] for org in reversed_data}

# %%
transitions = pd.DataFrame.from_dict(orgs_count, orient='index', columns=['count', 'org'])

# %%
data
# Out:
#                       company_file    inn_file  \
# 0     «КТЗ», промышленный оператор  9704082895
# 1                  «Автомир-Трейд»  7730569353
# 2                  «Джи Пи Си Рус»  7703400140
# 3           «Самотлорнефтепромхим»  8603118208
# 4                  «Мосметрострой»  7710068052
# ..                             ...         ...
# 583                       X5 Group  7733571872
# 584                            РЖД  7708503727
# 585  «Роснефть», нефтяная компания  7706107510
# 586                       «ЛУКОЙЛ»  7708004767
# 587                      «Газпром»  7736050003
#
#                                          industry_file inn_smi_publications  \
# 0                                     оптовая торговля           9704082895
# 1                                   розничная торговля           7730569353
# 2                                     платежный сервис           7703400140
# 3                                   сервисные компании           8603118208
# 4    инжиниринг, промышленно-инфраструктурное строи...           7710068052
# ..                                                 ...                  ...
# 583                                 розничная торговля                  NaN
# 584                              транспорт и логистика                  NaN
# 585             нефтяная и нефтегазовая промышленность                  NaN
# 586             нефтяная и нефтегазовая промышленность                  NaN
# 587             нефтяная и нефтегазовая промышленность                  NaN
#
#     inn_company_main_cards
# 0               9704082895
# 1               7730569353
# 2               7703400140
# 3               8603118208
# 4               7710068052
# ..                     ...
# 583                    NaN
# 584                    NaN
# 585                    NaN
# 586                    NaN
# 587                    NaN
#
# [588 rows x 5 columns]

# %%
transitions_more_1 = transitions[transitions['count'] > 1].sort_values(by=['count'], ascending=False)
transitions_less_1 = transitions[transitions['count'] <= 1].sort_values(by=['count'], ascending=False)

# %%
print(f'1) Размерноссть выборки: {transitions.shape[0]}')
print(f'2) Размерноссть выборки, в которой есть 2 и более компаний с совпадением: {transitions_more_1.shape[0]}')
print(f'3) Размерноссть выборки, в которой нет 2 и более компаний с совпадением: {transitions_less_1.shape[0]}')
print(f'Отношение 2)/3): {transitions_more_1.shape[0] / transitions_less_1.shape[0]}')
# Out:
# 1) Размерноссть выборки: 1220
# 2) Размерноссть выборки, в которой есть 2 и более компаний с совпадением: 456
# 3) Размерноссть выборки, в которой нет 2 и более компаний с совпадением: 764
# Отношение 2)/3): 0.5968586387434555

# %%
transitions_more_1['count'].value_counts()
# Out:
# count
# 3    455
# 2      1
# Name: count, dtype: int64

# %%
transitions_more_1['count'].hist()
# Out:
# <Axes: >

# %%
transitions_more_1['org'].to_list()

# %% [markdown]
# ## Основная карточка компании

# %%
data_for_info
# Out:
#                                           company_file    inn_file  \
# 0                         «КТЗ», промышленный оператор  9704082895
# 1                                      «Автомир-Трейд»  7730569353
# 2                                      «Джи Пи Си Рус»  7703400140
# 3                               «Самотлорнефтепромхим»  8603118208
# 4                                      «Мосметрострой»  7710068052
# ..                                                 ...         ...
# 571                       «Мегаполис», группа компаний  5003052454
# 573                                 «Транснефть» (ПАО)  7706061801
# 576  ПАО «Новолипецкий металлургический комбинат» (...  4823006703
# 583                                           X5 Group  7733571872
# 585                      «Роснефть», нефтяная компания  7706107510
#
#                                          industry_file inn_smi_publications  \
# 0                                     оптовая торговля           9704082895
# 1                                   розничная торговля           7730569353
# 2                                     платежный сервис           7703400140
# 3                                   сервисные компании           8603118208
# 4    инжиниринг, промышленно-инфраструктурное строи...           7710068052
# ..                                                 ...                  ...
# 571                                   оптовая торговля           5003052454
# 573                              транспорт и логистика           7706061801
# 576                                 черная металлургия           4823006703
# 583                                 розничная торговля           7733571872
# 585             нефтяная и нефтегазовая промышленность           7706107510
#
#     inn_company_main_cards  open_orgs_checker
# 0               9704082895                1.0
# 1               7730569353                1.0
# 2               7703400140                1.0
# 3               8603118208                1.0
# 4               7710068052                1.0
# ..                     ...                ...
# 571             5003052454                1.0
# 573             7706061801                1.0
# 576             4823006703                1.0
# 583             7733571872                1.0
# 585             7706107510                1.0
#
# [479 rows x 6 columns]

# %%
company_main_cards_path = path+'company_main_cards/'

lst_of_companies = (data_for_info['inn_file'] + '.html').to_list()

# %%
def main_card_crawler(file_name):
  with open(company_main_cards_path+file_name, 'r') as f:

    contents = f.read()
    soup = BeautifulSoup(contents, 'lxml')

  dom = etree.HTML(str(soup))
  company_main_info = {}
  for i in range(1,5):
    info_type = dom.xpath(f'/html/body/div/div[1]/div[1]/div[1]/div[1]/div/div/div[2]/div/span[{i}]/span/span/span/span/text()')[0][:-1]
    info = dom.xpath(f'/html/body/div/div[1]/div[1]/div[1]/div[1]/div/div/div[2]/div/span[{i}]/span/span/span/span/span/span/span/text()')[0]
    company_main_info[info_type] = info

  info_types = soup.find('table', {'class':'sp-properties-form sp-properties-form_compact'}).find_all('td', {"class": "sp-properties-form__label"})
  infos= soup.find('table', {'class':'sp-properties-form sp-properties-form_compact'}).find_all('td', {"class": "sp-properties-form__value"})
  for i in range(len(info_types)):
    info_type = unicodedata.normalize("NFKD", info_types[i].text)
    info = unicodedata.normalize("NFKD", infos[i].text)
    company_main_info[info_type] = info

  return company_main_info

# %%
main_card_info = []

for comp in lst_of_companies:
  print(comp)
  main_card_info.append(main_card_crawler(comp))
# Out:
# 9704082895.html
# 7730569353.html
# 7703400140.html
# 8603118208.html
# 7710068052.html
# 1655049111.html
# 7709340842.html
# 9718221490.html
# 7719022542.html
# 7714775020.html
# 5042060699.html
# 7704758153.html
# 5029104266.html
# 7838418751.html
# 2315995868.html
# 5403145086.html
# 5047172389.html
# 1654035998.html
# 4826022365.html
# 7705639173.html
# 7727696432.html
# 1655189422.html
# 6632004667.html
# 7710698978.html
# 7701655865.html
# 6663003800.html
# 7732121736.html
# 5046001101.html
# 4623004836.html
# 7717127211.html
# 5047105054.html
# 2922008546.html
# 4633037968.html
# 3814007314.html
# 3305051742.html
# 7703295463.html
# 7810022460.html
# 5609087920.html
# 6229024796.html
# 9705118142.html
# 7707205911.html
# 6732075238.html
# 7709583813.html
# 3811125221.html
# 7730107662.html
# 7701004101.html
# 5001048893.html
# 4725001168.html
# 9715239467.html
# 4203001913.html
# 7811657720.html
# 7709976356.html
# 7718538045.html
# 7705189397.html
# 7705532790.html
# 7830001028.html
# 4216001565.html
# 7706236515.html
# 7703106050.html
# 7017286512.html
# 1001228754.html
# 7428007317.html
# 7702192017.html
# 7705005321.html
# 5827901723.html
# 4252012308.html
# 7710761161.html
# 7731530768.html
# 7729507377.html
# 7716641537.html
# 7705058323.html
# 8904075533.html
# 7702352454.html
# 5030041780.html
# 7814581879.html
# 3812100526.html
# 3328430578.html
# 7327067461.html
# 7839326623.html
# 7719555477.html
# 7703248907.html
# 7810349385.html
# 7706739893.html
# 7703635416.html
# 3328426780.html
# 5443005705.html
# 7731316845.html
# 7736588909.html
# 7701879760.html
# 2308091759.html
# 7810249327.html
# 4633042206.html
# 7704459330.html
# 7729657870.html
# 5501100816.html
# 7706288496.html
# 7804568558.html
# 4205003440.html
# 6670413340.html
# 7705255201.html
# 7809008119.html
# 1650292810.html
# 7704579700.html
# 3905069220.html
# 3327122348.html
# 7709222373.html
# 7705772224.html
# 4214000252.html
# 7830000426.html
# 7705989700.html
# 6670381056.html
# 7826156685.html
# 1650161470.html
# 5007067042.html
# 7708797192.html
# 7717654289.html
# 7804069580.html
# 7720522853.html
# 6367052981.html
# 7730117815.html
# 7704216778.html
# 6025009824.html
# 7413000630.html
# 1659091192.html
# 7743101210.html
# 7701753020.html
# 7706241963.html
# 7734003657.html
# 5404151283.html
# 6164266561.html
# 7703068485.html
# 7709770002.html
# 7704537299.html
# 7705492690.html
# 7728115183.html
# 5904123809.html
# 7724338125.html
# 5604000700.html
# 4223035452.html
# 6234131659.html
# 4214033674.html
# 7701350084.html
# 7701380579.html
# 7101006354.html
# 7708607959.html
# 7703400608.html
# 7202197786.html
# 7703508520.html
# 7830000970.html
# 3123100360.html
# 5245000448.html
# 7710106212.html
# 7703374404.html
# 7725594604.html
# 7722582752.html
# 3250521869.html
# 5047095543.html
# 7704676655.html
# 5047149534.html
# 5044018861.html
# 2902060361.html
# 7706092944.html
# 7736655834.html
# 4715019631.html
# 5032292612.html
# 4027091179.html
# 7721147115.html
# 4345217731.html
# 5262218620.html
# 5407025576.html
# 7715034360.html
# 6671156423.html
# 1657036630.html
# 7118004789.html
# 8608049090.html
# 5260900010.html
# 7705935687.html
# 2352044518.html
# 7713628217.html
# 7705880068.html
# 7726044240.html
# 7703813034.html
# 5029169023.html
# 3252005997.html
# 8300120014.html
# 7743911253.html
# 4704012472.html
# 7721562305.html
# 7706017070.html
# 7719723690.html
# 7606053324.html
# 7743543232.html
# 7819301797.html
# 7728551510.html
# 7802312751.html
# 2720030404.html
# 7705018169.html
# 5038114542.html
# 7705098679.html
# 7704217309.html
# 4223055709.html
# 2465102746.html
# 7714724594.html
# 7721844807.html
# 7725776121.html
# 7712040285.html
# 7728795958.html
# 7802772445.html
# 8709009294.html
# 7743816842.html
# 7707803527.html
# 7707424367.html
# 7601001509.html
# 3122000300.html
# 5257003806.html
# 7704648707.html
# 7715397999.html
# 7714037390.html
# 8609000160.html
# 7722753969.html
# 7745000111.html
# 5603048611.html
# 1106019518.html
# 7104525439.html
# 3905011678.html
# 7701716677.html
# 7704244246.html
# 7731585968.html
# 7708678325.html
# 7717582404.html
# 7834005168.html
# 7705705370.html
# 2309001660.html
# 2465008567.html
# 7706277053.html
# 4028069779.html
# 4217204769.html
# 3328434156.html
# 7706800837.html
# 7726445147.html
# 5258054000.html
# 7827004484.html
# 6829012680.html
# 1651024807.html
# 7709678550.html
# 3913009739.html
# 7729588182.html
# 3110009570.html
# 7743580770.html
# 1831089218.html
# 7743578549.html
# 5003116490.html
# 1655202105.html
# 6606003385.html
# 6658388288.html
# 7730710905.html
# 7726059896.html
# 7017187800.html
# 5012000639.html
# 9701104646.html
# 6450925977.html
# 4205000908.html
# 6623074298.html
# 6606021264.html
# 9715010229.html
# 6167055777.html
# 7734445616.html
# 3321020710.html
# 7702842787.html
# 7701984274.html
# 0274036993.html
# 6607000556.html
# 5262036363.html
# 5611037405.html
# 7720403415.html
# 7714709349.html
# 5032048798.html
# 7729607406.html
# 5021013384.html
# 4025413896.html
# 7708525142.html
# 7710302785.html
# 7702764909.html
# 7732121398.html
# 7118018781.html
# 7705840940.html
# 7717625418.html
# 2328000083.html
# 7733646084.html
# 2451000818.html
# 7447010227.html
# 8603133326.html
# 6310000160.html
# 5032073106.html
# 7705634425.html
# 0268008010.html
# 7710044140.html
# 6166048181.html
# 4217107518.html
# 5024177951.html
# 7725104641.html
# 7204002873.html
# 7704630033.html
# 7730157021.html
# 1650131524.html
# 0264015786.html
# 7451279527.html
# 5258056945.html
# 7731537410.html
# 4217126359.html
# 7725216105.html
# 7709680944.html
# 7729265128.html
# 5913001268.html
# 5047210316.html
# 7802059185.html
# 7802849641.html
# 5406192366.html
# 9731058933.html
# 7725806898.html
# 5020037784.html
# 7705183476.html
# 9703017050.html
# 7704017596.html
# 7721793895.html
# 7720261827.html
# 7729481489.html
# 3528079131.html
# 7403005526.html
# 7838395215.html
# 5032277847.html
# 7729705354.html
# 5024048000.html
# 7803002209.html
# 7715568411.html
# 7713587786.html
# 7701215046.html
# 6671163413.html
# 4217102358.html
# 3808208157.html
# 7802348846.html
# 7706806518.html
# 7842337791.html
# 7729418511.html
# 2323025302.html
# 7733556360.html
# 7701791321.html
# 7722489009.html
# 3913501820.html
# 7718134701.html
# 1434045743.html
# 7708632345.html
# 8904047896.html
# 7704492055.html
# 7714617793.html
# 5260200603.html
# 7713085659.html
# 6901067107.html
# 6162015019.html
# 7714626332.html
# 2310175205.html
# 7725497022.html
# 7714186804.html
# 7804526950.html
# 2225074005.html
# 7017405576.html
# 7113502396.html
# 7714790325.html
# 7743543761.html
# 5075018950.html
# 7701639976.html
# 7743856281.html
# 7810245481.html
# 7743001840.html
# 2310040800.html
# 7728551528.html
# 7705133757.html
# 3913011336.html
# 7704582421.html
# 7713688946.html
# 7743792870.html
# 7714572888.html
# 7702521529.html
# 7708591995.html
# 6674121179.html
# 6671197148.html
# 7841322249.html
# 7710045520.html
# 0411075740.html
# 7709259743.html
# 5045016560.html
# 7718979307.html
# 5448100656.html
# 7702038150.html
# 5047076050.html
# 6685099285.html
# 2370000496.html
# 7734443270.html
# 7022000310.html
# 7729355029.html
# 5009072150.html
# 5074053542.html
# 6151012111.html
# 6670061296.html
# 8910002621.html
# 7811365157.html
# 6165161667.html
# 5257056036.html
# 7704548011.html
# 5036065113.html
# 7017094419.html
# 7726311464.html
# 7727162286.html
# 7826087713.html
# 5247004695.html
# 4234001215.html
# 7705739450.html
# 7743931676.html
# 4028021946.html
# 7706284124.html
# 3122503751.html
# 7701885820.html
# 7721040281.html
# 7704218694.html
# 7704784450.html
# 7728278043.html
# 7703623202.html
# 7721546864.html
# 7705060700.html
# 5047085094.html
# 7703270067.html
# 7712107050.html
# 5408130693.html
# 7713056834.html
# 4716016979.html
# 7707743204.html
# 3906072056.html
# 7728731619.html
# 5047045359.html
# 4205049090.html
# 1650032058.html
# 7719269331.html
# 7707016368.html
# 7728674093.html
# 6606013640.html
# 7703608910.html
# 7705541227.html
# 8904002359.html
# 6320002223.html
# 5911029807.html
# 7723199790.html
# 7715354473.html
# 5036045205.html
# 7707017509.html
# 7713076301.html
# 7710390358.html
# 7703386329.html
# 7812014560.html
# 5042059767.html
# 5047254063.html
# 7707767220.html
# 7703370008.html
# 7736216869.html
# 7736520080.html
# 7736035485.html
# 5029069967.html
# 7708619320.html
# 7703647595.html
# 7707548740.html
# 7814148471.html
# 7712040126.html
# 7709602713.html
# 2540167061.html
# 7727547261.html
# 5003052454.html
# 7706061801.html
# 4823006703.html
# 7733571872.html
# 7706107510.html

# %%
main_card_info_df = pd.DataFrame(main_card_info)

# %%
main_card_info_df
# Out:
#               ОГРН         ИНН        КПП      ОКПО  \
# 0    1217700375991  9704082895  210001001  51974376
# 1    1077761079263  7730569353  771801001  83121511
# 2    1157746967510  7703400140  774301001  51166895
# 3    1048600521408  8603118208  860301001  74733014
# 4    1027739002378  7710068052  770701001  01387120
# ..             ...         ...        ...       ...
# 474  1045000923967  5003052454  500301001  75219395
# 475  1027700049486  7706061801  770301001  00044463
# 476  1024800823123  4823006703  482301001  05757665
# 477  1067746744955  7733571872  773301001  96042871
# 478  1027700043502  7706107510  770601001  00044428
#
#                                    Полное наименование  \
# 0    ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КОН...
# 1    ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АВТ...
# 2    ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ДЖИ...
# 3          АКЦИОНЕРНОЕ ОБЩЕСТВО "САМОТЛОРНЕФТЕПРОМХИМ"
# 4       АКЦИОНЕРНОЕ ОБЩЕСТВО "МОСКОВСКИЙ МЕТРОСТРОЙ"
# ..                                                 ...
# 474  АКЦИОНЕРНОЕ ОБЩЕСТВО "ТОРГОВАЯ КОМПАНИЯ "МЕГАП...
# 475        ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "ТРАНСНЕФТЬ"
# 476  ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "НОВОЛИПЕЦКИЙ ...
# 477  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИКС...
# 478  ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "НЕФТЯНАЯ КОМПА...
#
#                                   Прежние наименования  \
# 0                                           УК ТМ, ООО
# 1                                    АВТОМИР-ФИЛИ, ООО
# 2                                                  NaN
# 3                             САМОТЛОРНЕФТЕПРОМХИМ, АО
# 4                         МОСКОВСКИЙ МЕТРОСТРОЙ, АО
# ..                                                 ...
# 474                    ТОРГОВАЯ КОМПАНИЯ МЕГАПОЛИС, АО
# 475  АКЦИОНЕРНАЯ КОМПАНИЯ ПО ТРАНСПОРТУ НЕФТИ ТРАНС...
# 476      НОВОЛИПЕЦКИЙ МЕТАЛЛУРГИЧЕСКИЙ КОМБИНАТ, ОАО
# 477                          КОРПОРАТИВНЫЙ ЦЕНТР, ООО
# 478                    НЕФТЯНАЯ КОМПАНИЯ РОСНЕФТЬ, ОАО
#
#            Другие наименования  \
# 0                    ООО "КТЗ"
# 1         ООО "АВТОМИР-ТРЕЙД"
# 2          ООО "ДЖИ ПИ СИ РУС"
# 3                     АО"СНПХ"
# 4          АО "МОСМЕТРОСТРОЙ"
# ..                         ...
# 474         АО "ТК "МЕГАПОЛИС"
# 475           ПАО "ТРАНСНЕФТЬ"
# 476                 ПАО "НЛМК"
# 477  ООО "ИКС 5 РИТЕЙЛ ГРУПП"
# 478         ПАО "НК "РОСНЕФТЬ"
#
#                                        На английском  \
# 0                          LLC "TRACTOR PLANTS GROUP"
# 1                                 LLC "AVTOMIR-TRADE"
# 2                                OOO "DZHI PI SI RUS"
# 3                                           AO"SNPKH"
# 4                                   Mosmetrostroy JSC
# ..                                                ...
# 474                       Trade Company Megapolis JSC
# 475  OIL TRANSPORTING JOINT STOCK COMPANY "TRANSNEFT"
# 476                            PJSC NOVOLIPETSK STEEL
# 477                                   X5 RETAIL GROUP
# 478                          Rosneft Oil Company PJSC
#
#                                                  Адрес  \
# 0    428003, Чувашская Республика - Чувашия, г.о. г...
# 1    107497, г. Москва, ул. Иркутская, д. 5/6 стр. ...
# 2    125195, г. Москва, вн.тер.г. муниципальный ок...
# 3    628616, Ханты-Мансийский Автономный Округ -...
# 4    127051, г. Москва, бульвар Цветной, д. 17 пом...
# ..                                                 ...
# 474  142718, Московская обл., г. Видное, с. Булатни...
# 475  123112, г. Москва, набережная Пресненская, д. ...
# 476  398040, Липецкая обл., г. Липецк, пл. Металлур...
# 477     125368, г. Москва, пер. Ангелов, д. 7На карте
# 478  115035, г. Москва, набережная Софийская, д. 2...
#
#                                   Телефон                              Web  \
# 0    +7 (499) 4262556 ·  Открытые данные              uk-tm.ru   · 1 домен
# 1                                     NaN                              NaN
# 2                       +7 (928) 1214313          gpc-store.ru   · 1 домен
# 3                       +7 (3466) 671363                    www.snph.biz
# 4                       +7 (495) 2767789   www.metrostroy.com   · 3 домена
# ..                                    ...                              ...
# 474                     +7 (3473) 286350         www.gkm.ru   · 19 доменов
# 475                     +7 (495) 9508067     www.transneft.ru   · 21 домен
# 476                     +7 (474) 2440041         www.nlmk.ru   · 52 домена
# 477       +7 (495) 6628888 (Доб. 41-265)               икс5.рф   · 1 домен
# 478                     +7 (495) 5178080     www.rosneft.ru   · 59 доменов
#
#                                          ОКОПФ  \
# 0    Общества с ограниченной ответственностью
# 1    Общества с ограниченной ответственностью
# 2    Общества с ограниченной ответственностью
# 3             Непубличные акционерные общества
# 4             Непубличные акционерные общества
# ..                                         ...
# 474           Непубличные акционерные общества
# 475             Публичные акционерные общества
# 476             Публичные акционерные общества
# 477  Общества с ограниченной ответственностью
# 478             Публичные акционерные общества
#
#                                                Отрасль  \
# 0        Деятельность по управлению холдинг-компаниями
# 1    Торговля розничная легковыми автомобилями и ле...
# 2    Торговля розничная моторным топливом в специал...
# 3    Предоставление услуг в области добычи нефти и ...
# 4                 Строительство железных дорог и метро
# ..                                                 ...
# 474               Торговля оптовая табачными изделиями
# 475  Транспортирование по трубопроводам нефти и неф...
# 476  Производство листового холоднокатаного стально...
# 477  Консультирование по вопросам коммерческой дея...
# 478                                       Добыча нефти
#
#                                           Руководитель  \
# 0    Водопьянов Андрей Валентинович · генеральный...
# 1    Рябушко Владимир Николаевич · генеральный дир...
# 2              Сазонов Евгений Валерьевич · президент
# 3    Галимьянов Ильфат Даниярович · генеральный ди...
# 4    Жуков Сергей Анатольевич · генеральный директор
# ..                                                 ...
# 474    Султанов Шамиль Рифович · генеральный директор
# 475              Токарев Николай Петрович · президент
# 476  Каратаев Сергей Михайлович · президент (пред...
# 477  Гайнуллина Наталья Фанисовна · генеральный д...
# 478  Сечин Игорь Иванович · главный исполнительныи...
#
#                            E-mail  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                 snph@nptus.ru
# 4    reception-3@metrostroy.com
# ..                            ...
# 474         reception_go@gkm.ru
# 475    maletsmn@ak.transneft.ru
# 476       arnautova_mn@nlmk.com
# 477                           NaN
# 478          a_panov@rosneft.ru
#
#                                             Соцсети Управляющая компания  \
# 0                                               NaN                  NaN
# 1                                               NaN                  NaN
# 2                                               NaN                  NaN
# 3                                               NaN                  NaN
# 4    youtube.com/channel/uc4ckqh0buo49a-xn-_byxng                    NaN
# ..                                              ...                  ...
# 474                                             NaN                  NaN
# 475                      vk.com/transneftofficial                    NaN
# 476                                             NaN                  NaN
# 477                                             NaN                  NaN
# 478                              vk.com/rosneftru                    NaN
#
#     Бенефициар
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 474        NaN
# 475        NaN
# 476        NaN
# 477        NaN
# 478        NaN
#
# [479 rows x 18 columns]

# %%
result = pd.merge(data_for_info, main_card_info_df, left_on='inn_file', right_on='ИНН', how='inner')

# %%
result.to_csv('/content/drive/MyDrive/ДИПЛОМ/Списки компаний/Итоговые фреймы данных/result.csv', sep=';', index=False)

# %%
data_for_info
# Out:
#                                           company_file    inn_file  \
# 0                         «КТЗ», промышленный оператор  9704082895
# 1                                      «Автомир-Трейд»  7730569353
# 2                                      «Джи Пи Си Рус»  7703400140
# 3                               «Самотлорнефтепромхим»  8603118208
# 4                                      «Мосметрострой»  7710068052
# ..                                                 ...         ...
# 571                       «Мегаполис», группа компаний  5003052454
# 573                                 «Транснефть» (ПАО)  7706061801
# 576  ПАО «Новолипецкий металлургический комбинат» (...  4823006703
# 583                                           X5 Group  7733571872
# 585                      «Роснефть», нефтяная компания  7706107510
#
#                                          industry_file inn_smi_publications  \
# 0                                     оптовая торговля           9704082895
# 1                                   розничная торговля           7730569353
# 2                                     платежный сервис           7703400140
# 3                                   сервисные компании           8603118208
# 4    инжиниринг, промышленно-инфраструктурное строи...           7710068052
# ..                                                 ...                  ...
# 571                                   оптовая торговля           5003052454
# 573                              транспорт и логистика           7706061801
# 576                                 черная металлургия           4823006703
# 583                                 розничная торговля           7733571872
# 585             нефтяная и нефтегазовая промышленность           7706107510
#
#     inn_company_main_cards  open_orgs_checker
# 0               9704082895                1.0
# 1               7730569353                1.0
# 2               7703400140                1.0
# 3               8603118208                1.0
# 4               7710068052                1.0
# ..                     ...                ...
# 571             5003052454                1.0
# 573             7706061801                1.0
# 576             4823006703                1.0
# 583             7733571872                1.0
# 585             7706107510                1.0
#
# [479 rows x 6 columns]

# %%
pd.merge

# %%
pd.DataFrame(main_card_info)
# Out:
#               ОГРН         ИНН        КПП      ОКПО  \
# 0    1217700375991  9704082895  210001001  51974376
# 1    1077761079263  7730569353  771801001  83121511
# 2    1157746967510  7703400140  774301001  51166895
# 3    1048600521408  8603118208  860301001  74733014
# 4    1027739002378  7710068052  770701001  01387120
# ..             ...         ...        ...       ...
# 474  1045000923967  5003052454  500301001  75219395
# 475  1027700049486  7706061801  770301001  00044463
# 476  1024800823123  4823006703  482301001  05757665
# 477  1067746744955  7733571872  773301001  96042871
# 478  1027700043502  7706107510  770601001  00044428
#
#                                    Полное наименование  \
# 0    ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "КОН...
# 1    ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "АВТ...
# 2    ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ДЖИ...
# 3          АКЦИОНЕРНОЕ ОБЩЕСТВО "САМОТЛОРНЕФТЕПРОМХИМ"
# 4       АКЦИОНЕРНОЕ ОБЩЕСТВО "МОСКОВСКИЙ МЕТРОСТРОЙ"
# ..                                                 ...
# 474  АКЦИОНЕРНОЕ ОБЩЕСТВО "ТОРГОВАЯ КОМПАНИЯ "МЕГАП...
# 475        ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "ТРАНСНЕФТЬ"
# 476  ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "НОВОЛИПЕЦКИЙ ...
# 477  ОБЩЕСТВО С ОГРАНИЧЕННОЙ ОТВЕТСТВЕННОСТЬЮ "ИКС...
# 478  ПУБЛИЧНОЕ АКЦИОНЕРНОЕ ОБЩЕСТВО "НЕФТЯНАЯ КОМПА...
#
#                                   Прежние наименования  \
# 0                                           УК ТМ, ООО
# 1                                    АВТОМИР-ФИЛИ, ООО
# 2                                                  NaN
# 3                             САМОТЛОРНЕФТЕПРОМХИМ, АО
# 4                         МОСКОВСКИЙ МЕТРОСТРОЙ, АО
# ..                                                 ...
# 474                    ТОРГОВАЯ КОМПАНИЯ МЕГАПОЛИС, АО
# 475  АКЦИОНЕРНАЯ КОМПАНИЯ ПО ТРАНСПОРТУ НЕФТИ ТРАНС...
# 476      НОВОЛИПЕЦКИЙ МЕТАЛЛУРГИЧЕСКИЙ КОМБИНАТ, ОАО
# 477                          КОРПОРАТИВНЫЙ ЦЕНТР, ООО
# 478                    НЕФТЯНАЯ КОМПАНИЯ РОСНЕФТЬ, ОАО
#
#            Другие наименования  \
# 0                    ООО "КТЗ"
# 1         ООО "АВТОМИР-ТРЕЙД"
# 2          ООО "ДЖИ ПИ СИ РУС"
# 3                     АО"СНПХ"
# 4          АО "МОСМЕТРОСТРОЙ"
# ..                         ...
# 474         АО "ТК "МЕГАПОЛИС"
# 475           ПАО "ТРАНСНЕФТЬ"
# 476                 ПАО "НЛМК"
# 477  ООО "ИКС 5 РИТЕЙЛ ГРУПП"
# 478         ПАО "НК "РОСНЕФТЬ"
#
#                                        На английском  \
# 0                          LLC "TRACTOR PLANTS GROUP"
# 1                                 LLC "AVTOMIR-TRADE"
# 2                                OOO "DZHI PI SI RUS"
# 3                                           AO"SNPKH"
# 4                                   Mosmetrostroy JSC
# ..                                                ...
# 474                       Trade Company Megapolis JSC
# 475  OIL TRANSPORTING JOINT STOCK COMPANY "TRANSNEFT"
# 476                            PJSC NOVOLIPETSK STEEL
# 477                                   X5 RETAIL GROUP
# 478                          Rosneft Oil Company PJSC
#
#                                                  Адрес  \
# 0    428003, Чувашская Республика - Чувашия, г.о. г...
# 1    107497, г. Москва, ул. Иркутская, д. 5/6 стр. ...
# 2    125195, г. Москва, вн.тер.г. муниципальный ок...
# 3    628616, Ханты-Мансийский Автономный Округ -...
# 4    127051, г. Москва, бульвар Цветной, д. 17 пом...
# ..                                                 ...
# 474  142718, Московская обл., г. Видное, с. Булатни...
# 475  123112, г. Москва, набережная Пресненская, д. ...
# 476  398040, Липецкая обл., г. Липецк, пл. Металлур...
# 477     125368, г. Москва, пер. Ангелов, д. 7На карте
# 478  115035, г. Москва, набережная Софийская, д. 2...
#
#                                   Телефон                              Web  \
# 0    +7 (499) 4262556 ·  Открытые данные              uk-tm.ru   · 1 домен
# 1                                     NaN                              NaN
# 2                       +7 (928) 1214313          gpc-store.ru   · 1 домен
# 3                       +7 (3466) 671363                    www.snph.biz
# 4                       +7 (495) 2767789   www.metrostroy.com   · 3 домена
# ..                                    ...                              ...
# 474                     +7 (3473) 286350         www.gkm.ru   · 19 доменов
# 475                     +7 (495) 9508067     www.transneft.ru   · 21 домен
# 476                     +7 (474) 2440041         www.nlmk.ru   · 52 домена
# 477       +7 (495) 6628888 (Доб. 41-265)               икс5.рф   · 1 домен
# 478                     +7 (495) 5178080     www.rosneft.ru   · 59 доменов
#
#                                          ОКОПФ  \
# 0    Общества с ограниченной ответственностью
# 1    Общества с ограниченной ответственностью
# 2    Общества с ограниченной ответственностью
# 3             Непубличные акционерные общества
# 4             Непубличные акционерные общества
# ..                                         ...
# 474           Непубличные акционерные общества
# 475             Публичные акционерные общества
# 476             Публичные акционерные общества
# 477  Общества с ограниченной ответственностью
# 478             Публичные акционерные общества
#
#                                                Отрасль  \
# 0        Деятельность по управлению холдинг-компаниями
# 1    Торговля розничная легковыми автомобилями и ле...
# 2    Торговля розничная моторным топливом в специал...
# 3    Предоставление услуг в области добычи нефти и ...
# 4                 Строительство железных дорог и метро
# ..                                                 ...
# 474               Торговля оптовая табачными изделиями
# 475  Транспортирование по трубопроводам нефти и неф...
# 476  Производство листового холоднокатаного стально...
# 477  Консультирование по вопросам коммерческой дея...
# 478                                       Добыча нефти
#
#                                           Руководитель  \
# 0    Водопьянов Андрей Валентинович · генеральный...
# 1    Рябушко Владимир Николаевич · генеральный дир...
# 2              Сазонов Евгений Валерьевич · президент
# 3    Галимьянов Ильфат Даниярович · генеральный ди...
# 4    Жуков Сергей Анатольевич · генеральный директор
# ..                                                 ...
# 474    Султанов Шамиль Рифович · генеральный директор
# 475              Токарев Николай Петрович · президент
# 476  Каратаев Сергей Михайлович · президент (пред...
# 477  Гайнуллина Наталья Фанисовна · генеральный д...
# 478  Сечин Игорь Иванович · главный исполнительныи...
#
#                            E-mail  \
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                 snph@nptus.ru
# 4    reception-3@metrostroy.com
# ..                            ...
# 474         reception_go@gkm.ru
# 475    maletsmn@ak.transneft.ru
# 476       arnautova_mn@nlmk.com
# 477                           NaN
# 478          a_panov@rosneft.ru
#
#                                             Соцсети Управляющая компания  \
# 0                                               NaN                  NaN
# 1                                               NaN                  NaN
# 2                                               NaN                  NaN
# 3                                               NaN                  NaN
# 4    youtube.com/channel/uc4ckqh0buo49a-xn-_byxng                    NaN
# ..                                              ...                  ...
# 474                                             NaN                  NaN
# 475                      vk.com/transneftofficial                    NaN
# 476                                             NaN                  NaN
# 477                                             NaN                  NaN
# 478                              vk.com/rosneftru                    NaN
#
#     Бенефициар
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 474        NaN
# 475        NaN
# 476        NaN
# 477        NaN
# 478        NaN
#
# [479 rows x 18 columns]
