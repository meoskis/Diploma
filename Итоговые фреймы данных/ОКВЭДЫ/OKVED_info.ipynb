# %%
import pandas as pd
import numpy as np

# %%
data_full = pd.read_csv('/content/drive/MyDrive/ДИПЛОМ/Списки компаний/Итоговые фреймы данных/ОКВЭДЫ/Okved_Dataset-master/code_full.csv')
data_level_1 = pd.read_csv('/content/drive/MyDrive/ДИПЛОМ/Списки компаний/Итоговые фреймы данных/ОКВЭДЫ/Okved_Dataset-master/code_level_1.csv')
data_level_2 = pd.read_csv('/content/drive/MyDrive/ДИПЛОМ/Списки компаний/Итоговые фреймы данных/ОКВЭДЫ/Okved_Dataset-master/code_level_2.csv')
sections = pd.read_csv('/content/drive/MyDrive/ДИПЛОМ/Списки компаний/Итоговые фреймы данных/ОКВЭДЫ/Okved_Dataset-master/sections.csv')

# %%
data
# Out:
#      Section      Code  Main_code Sup_code Sub_code  \
# 0          A  01                1
# 1          A  01.1              1       1
# 2          A  01.11             1       11
# 3          A  01.11.1           1       11        1
# 4          A  01.11.11          1       11        1
# ...      ...       ...        ...      ...      ...
# 2765       T  98.2             98       2
# 2766       T  98.20            98       20
# 2767       U  99               99
# 2768       U  99.0             99       0
# 2769       U  99.00            99       00
#
#                                             Description
# 0     Растениеводство и животноводство, охота и пред...
# 1     Выращивание однолетних культур                ...
# 2     Выращивание зерновых (кроме риса), зернобобовы...
# 3     Выращивание зерновых культур                  ...
# 4     Выращивание пшеницы                           ...
# ...                                                 ...
# ...

# %%
data_level_1
# Out:
#    Section  Code  Main_code                                        Description
# 0        A     1          1  Растениеводство и животноводство, охота и пред...
# 1        A     2          2  Лесоводство и лесозаготовки                   ...
# 2        A     3          3  Рыболовство и рыбоводство                     ...
# 3        B     5          5  Добыча угля                                   ...
# 4        B     6          6  Добыча сырой нефти и природного газа          ...
# ..     ...   ...        ...                                                ...
# 83       S    95         95  Ремонт компьютеров, предметов личного потребле...
# 84       S    96         96  Деятельность по предоставлению прочих персонал...
# 85       T    97         97  Деятельность домашних хозяйств с наемными рабо...
# 86       T    98         98  Деятельность недифференцированная частных дома...
# 87       U    99         99  Деятельность экстерриториальных организаций и ...
#
# [88 rows x 4 columns]

# %%
data_level_2
# Out:
#     Section   Code  Main_code  Sup_code  \
# 0         A   1.10          1         1
# 1         A   1.11          1        11
# 2         A   1.12          1        12
# 3         A   1.13          1        13
# 4         A   1.14          1        14
# ..      ...    ...        ...       ...
# 890       T  98.10         98        10
# 891       T  98.20         98         2
# 892       T  98.20         98        20
# 893       U  99.00         99         0
# 894       U  99.00         99         0
#
#                                            Description
# 0    Выращивание однолетних культур                ...
# 1    Выращивание зерновых (кроме риса), зернобобовы...
# 2    Выращивание риса                              ...
# 3    Выращивание овощей, бахчевых, корнеплодных и к...
# 4    Выращивание сахарного тростника               ...
# ..                                                 ...
# 890  Деятельность недифференцированная частных дома...
# ...

# %%
sections
# Out:
#    Section                                        Description
# 0        A  СЕЛЬСКОЕ, ЛЕСНОЕ ХОЗЯЙСТВО, ОХОТА, РЫБОЛОВСТВО...
# 1        B  ДОБЫЧА ПОЛЕЗНЫХ ИСКОПАЕМЫХ                    ...
# 2        C  ОБРАБАТЫВАЮЩИЕ ПРОИЗВОДСТВА                   ...
# 3        D  ОБЕСПЕЧЕНИЕ ЭЛЕКТРИЧЕСКОЙ ЭНЕРГИЕЙ, ГАЗОМ И ПА...
# 4        E  ВОДОСНАБЖЕНИЕ; ВОДООТВЕДЕНИЕ, ОРГАНИЗАЦИЯ СБОР...
# 5        F  СТРОИТЕЛЬСТВО                                 ...
# 6        G  ТОРГОВЛЯ ОПТОВАЯ И РОЗНИЧНАЯ; РЕМОНТ АВТОТРАНС...
# 7        H  ТРАНСПОРТИРОВКА И ХРАНЕНИЕ                    ...
# 8        I  ДЕЯТЕЛЬНОСТЬ ГОСТИНИЦ И ПРЕДПРИЯТИЙ ОБЩЕСТВЕНН...
# 9        J  ДЕЯТЕЛЬНОСТЬ В ОБЛАСТИ ИНФОРМАЦИИ И СВЯЗИ     ...
# 10       K  ДЕЯТЕЛЬНОСТЬ ФИНАНСОВАЯ И СТРАХОВАЯ           ...
# 11       L  ДЕЯТЕЛЬНОСТЬ ПО ОПЕРАЦИЯМ С НЕДВИЖИМЫМ ИМУЩЕСТ...
# 12       M  ДЕЯТЕЛЬНОСТЬ ПРОФЕССИОНАЛЬНАЯ, НАУЧНАЯ И ТЕХНИ...
# 13       N  ДЕЯТЕЛЬНОСТЬ АДМИНИСТРАТИВНАЯ И СОПУТСТВУЮЩИЕ ...
# ...
