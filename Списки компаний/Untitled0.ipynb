# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
data = pd.read_excel('/content/drive/MyDrive/ДИПЛОМ/метрики.xlsx', index_col=0)

# %%
pd.read_excel?

# %%
data
# Out:
#                   Hits@1  Hits@2  Hits@3  Hits@5  Hits@10   MRR
# NGNN + GraphSage  0.5147  0.6034  0.6311  0.7421   0.8118  0.41
# NGNN + GCN        0.2196  0.5153  0.5743  0.6304   0.6807  0.14
# HGF               0.7002  0.7240  0.7692  0.8239   0.8923  0.65
# SEAL              0.3508  0.3949  0.4216  0.5034   0.5990  0.21
# GANTE             0.6560  0.6915  0.7103  0.7814   0.8230  0.51
# P-GNN             0.6806  0.7158  0.7448  0.8133   0.8766  0.54

# %%
data.columns
# Out:
# Index(['Hits@1', 'Hits@2', 'Hits@3', 'Hits@5', 'Hits@10', 'MRR'], dtype='object')

# %%
fig = px.bar(data[['Hits@1', 'Hits@2', 'Hits@3', 'Hits@5', 'Hits@10']], barmode='group',
             labels={'value':'Значение',
                     'index':'Наименование модели',
                     'variable':'Модели'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.bar(data['MRR'], barmode='group',
             labels={'value':'Значение',
                     'index':'Наименование модели',
                     'variable':'Модели'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
